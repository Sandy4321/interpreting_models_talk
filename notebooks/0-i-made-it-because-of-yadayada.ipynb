# %% [markdown]
# # Description

# %% [markdown]
# # Config

# %%
PATH_TO_DATA = "../data/external/adult.csv"

# %% [markdown]
# # Code

# %%
# !jupyter nbextension install --py --sys-prefix widgetsnbextension
# !jupyter nbextension enable --py --sys-prefix widgetsnbextension
# !pip install mlvis
# !jupyter nbextension install --py --symlink --sys-prefix mlvis
# !jupyter nbextension enable --py --sys-prefix mlvis
# Out:
# Installing /anaconda3/lib/python3.6/site-packages/widgetsnbextension/static -> jupyter-js-widgets
# Up to date: /anaconda3/share/jupyter/nbextensions/jupyter-js-widgets/extension.js.map
# Up to date: /anaconda3/share/jupyter/nbextensions/jupyter-js-widgets/extension.js
# - Validating: OK
#
#     To initialize this nbextension in the browser every time the notebook (or other app) loads:
#
#           jupyter nbextension enable widgetsnbextension --py --sys-prefix
#
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: OK
# Collecting mlvis
#   Downloading https://files.pythonhosted.org/packages/0b/fe/17a987d8cbc8df7f5d6272cd5238711c64db93c5762997aaef9f3a2f899d/mlvis-0.1.0-py3-none-any.whl (16.4MB)
#     100% |████████████████████████████████| 16.4MB 487kB/s ta 0:00:011
# Requirement already satisfied: traitlets in /anaconda3/lib/python3.6/site-packages (from mlvis) (4.3.2)
# Requirement already satisfied: ipywidgets in /anaconda3/lib/python3.6/site-packages (from mlvis) (7.4.2)
# Requirement already satisfied: pandas in /anaconda3/lib/python3.6/site-packages (from mlvis) (1.1.2)
# Requirement already satisfied: ipython_genutils in /anaconda3/lib/python3.6/site-packages (from traitlets->mlvis) (0.2.0)
# Requirement already satisfied: six in /anaconda3/lib/python3.6/site-packages (from traitlets->mlvis) (1.15.0)
# Requirement already satisfied: decorator in /anaconda3/lib/python3.6/site-packages (from traitlets->mlvis) (4.3.0)
# Requirement already satisfied: nbformat>=4.2.0 in /anaconda3/lib/python3.6/site-packages (from ipywidgets->mlvis) (4.4.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /anaconda3/lib/python3.6/site-packages (from ipywidgets->mlvis) (5.1.0)
# Requirement already satisfied: ipython>=4.0.0; python_version >= "3.3" in /anaconda3/lib/python3.6/site-packages (from ipywidgets->mlvis) (7.16.1)
# Requirement already satisfied: widgetsnbextension~=3.4.0 in /anaconda3/lib/python3.6/site-packages (from ipywidgets->mlvis) (3.4.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /anaconda3/lib/python3.6/site-packages (from pandas->mlvis) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /anaconda3/lib/python3.6/site-packages (from pandas->mlvis) (2020.1)
# Requirement already satisfied: numpy>=1.15.4 in /anaconda3/lib/python3.6/site-packages (from pandas->mlvis) (1.19.2)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /anaconda3/lib/python3.6/site-packages (from nbformat>=4.2.0->ipywidgets->mlvis) (3.0.0a3)
# Requirement already satisfied: jupyter_core in /anaconda3/lib/python3.6/site-packages (from nbformat>=4.2.0->ipywidgets->mlvis) (4.4.0)
# Requirement already satisfied: jupyter_client in /anaconda3/lib/python3.6/site-packages (from ipykernel>=4.5.1->ipywidgets->mlvis) (5.2.4)
# Requirement already satisfied: tornado>=4.2 in /anaconda3/lib/python3.6/site-packages (from ipykernel>=4.5.1->ipywidgets->mlvis) (5.1.1)
# Requirement already satisfied: appnope; sys_platform == "darwin" in /anaconda3/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->mlvis) (0.1.0)
# Requirement already satisfied: pickleshare in /anaconda3/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->mlvis) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in /anaconda3/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->mlvis) (42.0.2)
# Requirement already satisfied: pygments in /anaconda3/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->mlvis) (2.3.1)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /anaconda3/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->mlvis) (4.6.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /anaconda3/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->mlvis) (3.0.5)
# Requirement already satisfied: backcall in /anaconda3/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->mlvis) (0.1.0)
# Requirement already satisfied: jedi>=0.10 in /anaconda3/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->mlvis) (0.13.2)
# Requirement already satisfied: notebook>=4.4.1 in /anaconda3/lib/python3.6/site-packages (from widgetsnbextension~=3.4.0->ipywidgets->mlvis) (5.7.4)
# Requirement already satisfied: attrs>=17.4.0 in /anaconda3/lib/python3.6/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->mlvis) (20.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /anaconda3/lib/python3.6/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->mlvis) (0.14.9)
# Requirement already satisfied: pyzmq>=13 in /anaconda3/lib/python3.6/site-packages (from jupyter_client->ipykernel>=4.5.1->ipywidgets->mlvis) (17.1.2)
# Requirement already satisfied: ptyprocess>=0.5 in /anaconda3/lib/python3.6/site-packages (from pexpect; sys_platform != "win32"->ipython>=4.0.0; python_version >= "3.3"->ipywidgets->mlvis) (0.6.0)
# Requirement already satisfied: wcwidth in /anaconda3/lib/python3.6/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0; python_version >= "3.3"->ipywidgets->mlvis) (0.1.7)
# Requirement already satisfied: parso>=0.3.0 in /anaconda3/lib/python3.6/site-packages (from jedi>=0.10->ipython>=4.0.0; python_version >= "3.3"->ipywidgets->mlvis) (0.3.1)
# Requirement already satisfied: jinja2 in /anaconda3/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets->mlvis) (2.10)
# Requirement already satisfied: nbconvert in /anaconda3/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets->mlvis) (5.4.0)
# Requirement already satisfied: terminado>=0.8.1 in /anaconda3/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets->mlvis) (0.8.1)
# Requirement already satisfied: Send2Trash in /anaconda3/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets->mlvis) (1.5.0)
# Requirement already satisfied: prometheus-client in /anaconda3/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets->mlvis) (0.5.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /anaconda3/lib/python3.6/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets->mlvis) (1.1.0)
# Requirement already satisfied: mistune>=0.8.1 in /anaconda3/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets->mlvis) (0.8.4)
# Requirement already satisfied: entrypoints>=0.2.2 in /anaconda3/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets->mlvis) (0.3)
# Requirement already satisfied: bleach in /anaconda3/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets->mlvis) (3.1.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /anaconda3/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets->mlvis) (1.4.2)
# Requirement already satisfied: testpath in /anaconda3/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets->mlvis) (0.4.2)
# Requirement already satisfied: defusedxml in /anaconda3/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets->mlvis) (0.5.0)
# Requirement already satisfied: webencodings in /anaconda3/lib/python3.6/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets->mlvis) (0.5.1)
# Installing collected packages: mlvis
# Successfully installed mlvis-0.1.0
# Installing /anaconda3/lib/python3.6/site-packages/mlvis/static -> mlvis
# - Validating: OK
#
#     To initialize this nbextension in the browser every time the notebook (or other app) loads:
#
#           jupyter nbextension enable mlvis --py --sys-prefix
#
# Enabling notebook extension mlvis/extension...
#       - Validating: OK

# %%
from mlvis import Manifold
import sys, json, math
from random import uniform

# %%
import pandas as pd

# %%
data = pd.read_csv(PATH_TO_DATA)

# %%
data
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# 1      Married-civ-spouse    Farming-fishing      Husband  White    Male
# 2      Married-civ-spouse    Protective-serv      Husband  White    Male
# 3      Married-civ-spouse  Machine-op-inspct      Husband  Black    Male
# 4           Never-married                  ?    Own-child  White  Female
# ...                   ...                ...          ...    ...     ...
# 48837  Married-civ-spouse       Tech-support         Wife  White  Female
# 48838  Married-civ-spouse  Machine-op-inspct      Husband  White    Male
# 48839             Widowed       Adm-clerical    Unmarried  White  Female
# 48840       Never-married       Adm-clerical    Own-child  White    Male
# 48841  Married-civ-spouse    Exec-managerial         Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country income
# 0                 0             0              40  United-States  <=50K
# 1                 0             0              50  United-States  <=50K
# 2                 0             0              40  United-States   >50K
# 3              7688             0              40  United-States   >50K
# 4                 0             0              30  United-States  <=50K
# ...             ...           ...             ...            ...    ...
# 48837             0             0              38  United-States  <=50K
# 48838             0             0              40  United-States   >50K
# 48839             0             0              40  United-States  <=50K
# 48840             0             0              20  United-States  <=50K
# 48841         15024             0              40  United-States   >50K
#
# [48842 rows x 15 columns]
